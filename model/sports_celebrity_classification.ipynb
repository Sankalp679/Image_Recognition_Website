# %% [markdown]
# <h2 style='color:blue' align='center'>Sports Celebrity Image Classification<h2>

# %% [markdown]
# Special thanks to Debjyoti Paul (My data scientist friend at Amazon) for help with this project

# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# <h3 style='color:purple'>(1) Preprocessing: Detect face and eyes</h3>

# %% [markdown]
# #### When we look at any image, most of the time we identify a person using a face. An image might contain multiple faces, also the face can be obstructed and not clear. The first step in our pre-processing pipeline is to detect faces from an image. Once face is detected, we will detect eyes, if two eyes are detected then only we keep that image otherwise discard it.</h4>

# %% [markdown]
# #### Now how do you detect face and eyes?

# %% [markdown]
# We will use haar cascade from opencv for this. Here is an article on this: https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_objdetect/py_face_detection/py_face_detection.html?highlight=haar

# %%
img = cv2.imread('./test_images/Salman khan.jpg')
img.shape
# Out:
# (591, 474, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (591, 474)

# %%
gray
# Out:
# array([[  3,   3,   3, ...,   4,   4,   4],
#        [  3,   3,   3, ...,   4,   4,   4],
#        [  3,   3,   3, ...,   4,   4,   4],
#        ...,
#        [253, 254, 243, ...,  10,   2,  15],
#        [244, 253, 244, ...,  10,  24,  59],
#        [236, 254, 248, ...,  10,  11,  59]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[ 71, 157, 365, 365]], dtype=int32)

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (71, 157, 365, 365)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %% [markdown]
# <h3 style='color:purple'>(2) Preprocessing: Crop the facial region of the image</h3>

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (365, 365, 3)

# %% [markdown]
# <h3 style='color:purple'>(3) Preprocessing: Use wavelet transform as a feature for traning our model</h3>

# %% [markdown]
# #### In wavelet transformed image, you can see edges clearly and that can give us clues on various facial features such as eyes, nose, lips etc

# %% [markdown]
# ### Wavelet transform

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)
plt.imshow(im_har, cmap='gray')

# %% [markdown]
# #### You can see above a wavelet transformed image that gives clues on facial features such as eyes, nose, lips etc. This along with raw pixel image can be used as an input for our classifier

# %% [markdown]
# <h3 style='color:purple'>(3) Preprocessing: Load image, detect face. If eyes >=2, then save and crop the face region</h3>

# %% [markdown]
# ####  Lets write a python function that can take input image and returns cropped image (if face and eyes >=2 are detected)

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('./test_images/Salman khan.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/Salman khan.jpg')
try:
    cropped_image.shape
    plt.imshow(cropped_image)
except:
    print('0')

# %% [markdown]
# **In below image face is not very clear and it doesn't have two eyes clearly visible**

# %%
org_image_obstructed = cv2.imread('./test_images/Salman khan.jpg')
plt.imshow(org_image_obstructed)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/Salman khan.jpg')
try:
    cropped_image.shape
    plt.imshow(cropped_image)
except:
    print('0')

# %% [markdown]
# **Above cropped_image_no_2_eyes is None which means we should ignore this image and we will not use such image for model training**

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/Alia Bhatt',
#  './dataset/Deepika Padukone',
#  './dataset/Salman khan',
#  './dataset/Shahrukh Khan']

# %% [markdown]
# **Go through all images in dataset folder and create cropped images for them. There will be cropped folder inside dataset folder after you run this code**

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone36.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone360.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone361.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone362.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone363.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone364.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone365.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone366.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone367.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone37.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone38.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone39.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone4.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone40.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone41.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone42.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone43.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone44.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone45.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone46.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone47.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone48.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone49.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone5.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone50.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone51.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone52.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone53.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone54.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone55.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone56.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone57.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone58.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone59.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone6.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone60.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone61.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone62.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone63.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone64.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone65.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone66.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone67.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone68.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone69.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone7.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone70.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone71.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone72.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone73.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone74.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone75.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone76.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone77.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone78.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone79.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone8.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone80.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone81.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone82.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone83.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone84.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone85.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone86.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone87.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone88.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone89.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone9.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone90.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone91.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone92.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone93.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone94.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone95.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone96.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone97.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone98.png',
#   './dataset/cropped/Deepika Padukone\\Deepika Padukone99.png'],
#  'Salman khan': ['./dataset/cropped/Salman khan\\Salman khan1.png',
#   './dataset/cropped/Salman khan\\Salman khan10.png',
#   './dataset/cropped/Salman khan\\Salman khan100.png',
#   './dataset/cropped/Salman khan\\Salman khan101.png',
#   './dataset/cropped/Salman khan\\Salman khan102.png',
#   './dataset/cropped/Salman khan\\Salman khan103.png',
#   './dataset/cropped/Salman khan\\Salman khan104.png',
#   './dataset/cropped/Salman khan\\Salman khan105.png',
#   './dataset/cropped/Salman khan\\Salman khan106.png',
#   './dataset/cropped/Salman khan\\Salman khan107.png',
#   './dataset/cropped/Salman khan\\Salman khan108.png',
#   './dataset/cropped/Salman khan\\Salman khan109.png',
#   './dataset/cropped/Salman khan\\Salman khan11.png',
#   './dataset/cropped/Salman khan\\Salman khan110.png',
#   './dataset/cropped/Salman khan\\Salman khan111.png',
#   './dataset/cropped/Salman khan\\Salman khan112.png',
#   './dataset/cropped/Salman khan\\Salman khan113.png',
#   './dataset/cropped/Salman khan\\Salman khan114.png',
#   './dataset/cropped/Salman khan\\Salman khan115.png',
#   './dataset/cropped/Salman khan\\Salman khan116.png',
#   './dataset/cropped/Salman khan\\Salman khan117.png',
#   './dataset/cropped/Salman khan\\Salman khan118.png',
#   './dataset/cropped/Salman khan\\Salman khan119.png',
#   './dataset/cropped/Salman khan\\Salman khan12.png',
#   './dataset/cropped/Salman khan\\Salman khan120.png',
#   './dataset/cropped/Salman khan\\Salman khan121.png',
#   './dataset/cropped/Salman khan\\Salman khan122.png',
#   './dataset/cropped/Salman khan\\Salman khan123.png',
#   './dataset/cropped/Salman khan\\Salman khan124.png',
#   './dataset/cropped/Salman khan\\Salman khan125.png',
#   './dataset/cropped/Salman khan\\Salman khan126.png',
#   './dataset/cropped/Salman khan\\Salman khan127.png',
#   './dataset/cropped/Salman khan\\Salman khan128.png',
#   './dataset/cropped/Salman khan\\Salman khan129.png',
#   './dataset/cropped/Salman khan\\Salman khan13.png',
#   './dataset/cropped/Salman khan\\Salman khan130.png',
#   './dataset/cropped/Salman khan\\Salman khan131.png',
#   './dataset/cropped/Salman khan\\Salman khan132.png',
#   './dataset/cropped/Salman khan\\Salman khan133.png',
#   './dataset/cropped/Salman khan\\Salman khan134.png',
#   './dataset/cropped/Salman khan\\Salman khan135.png',
#   './dataset/cropped/Salman khan\\Salman khan136.png',
#   './dataset/cropped/Salman khan\\Salman khan137.png',
#   './dataset/cropped/Salman khan\\Salman khan138.png',
#   './dataset/cropped/Salman khan\\Salman khan139.png',
#   './dataset/cropped/Salman khan\\Salman khan14.png',
#   './dataset/cropped/Salman khan\\Salman khan140.png',
#   './dataset/cropped/Salman khan\\Salman khan141.png',
#   './dataset/cropped/Salman khan\\Salman khan142.png',
#   './dataset/cropped/Salman khan\\Salman khan143.png',
#   './dataset/cropped/Salman khan\\Salman khan144.png',
#   './dataset/cropped/Salman khan\\Salman khan145.png',
#   './dataset/cropped/Salman khan\\Salman khan146.png',
#   './dataset/cropped/Salman khan\\Salman khan147.png',
#   './dataset/cropped/Salman khan\\Salman khan148.png',
#   './dataset/cropped/Salman khan\\Salman khan149.png',
#   './dataset/cropped/Salman khan\\Salman khan15.png',
#   './dataset/cropped/Salman khan\\Salman khan150.png',
#   './dataset/cropped/Salman khan\\Salman khan151.png',
#   './dataset/cropped/Salman khan\\Salman khan152.png',
#   './dataset/cropped/Salman khan\\Salman khan153.png',
#   './dataset/cropped/Salman khan\\Salman khan154.png',
#   './dataset/cropped/Salman khan\\Salman khan155.png',
#   './dataset/cropped/Salman khan\\Salman khan156.png',
#   './dataset/cropped/Salman khan\\Salman khan157.png',
#   './dataset/cropped/Salman khan\\Salman khan158.png',
#   './dataset/cropped/Salman khan\\Salman khan159.png',
#   './dataset/cropped/Salman khan\\Salman khan16.png',
#   './dataset/cropped/Salman khan\\Salman khan160.png',
#   './dataset/cropped/Salman khan\\Salman khan161.png',
#   './dataset/cropped/Salman khan\\Salman khan162.png',
#   './dataset/cropped/Salman khan\\Salman khan163.png',
#   './dataset/cropped/Salman khan\\Salman khan164.png',
#   './dataset/cropped/Salman khan\\Salman khan165.png',
#   './dataset/cropped/Salman khan\\Salman khan166.png',
#   './dataset/cropped/Salman khan\\Salman khan167.png',
#   './dataset/cropped/Salman khan\\Salman khan168.png',
# ...
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan122.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan123.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan124.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan125.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan126.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan127.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan128.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan129.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan13.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan130.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan131.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan132.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan133.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan134.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan135.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan136.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan137.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan138.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan139.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan14.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan140.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan141.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan142.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan143.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan144.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan145.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan146.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan147.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan148.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan149.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan15.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan150.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan151.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan152.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan153.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan154.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan155.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan156.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan157.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan158.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan159.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan16.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan160.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan161.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan162.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan163.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan164.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan165.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan166.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan167.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan168.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan169.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan17.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan170.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan171.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan172.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan173.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan174.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan175.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan176.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan177.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan178.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan179.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan18.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan180.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan181.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan182.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan183.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan184.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan185.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan186.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan187.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan188.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan189.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan19.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan190.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan191.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan192.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan193.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan194.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan195.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan196.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan197.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan198.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan199.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan2.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan20.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan200.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan201.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan202.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan203.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan204.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan205.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan206.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan207.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan208.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan209.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan21.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan210.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan211.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan212.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan213.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan214.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan215.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan216.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan217.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan218.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan219.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan22.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan220.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan221.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan222.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan223.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan224.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan225.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan226.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan227.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan228.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan229.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan23.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan230.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan231.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan232.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan233.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan234.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan235.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan236.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan237.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan238.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan239.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan24.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan240.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan241.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan242.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan243.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan244.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan245.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan246.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan247.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan248.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan249.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan25.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan250.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan251.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan252.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan253.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan254.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan255.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan256.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan257.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan258.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan259.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan26.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan260.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan261.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan262.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan263.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan264.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan265.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan266.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan267.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan268.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan269.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan27.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan270.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan271.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan272.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan273.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan274.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan275.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan276.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan277.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan278.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan279.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan28.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan280.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan281.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan282.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan283.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan284.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan285.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan286.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan287.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan288.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan289.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan29.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan290.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan291.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan292.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan293.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan294.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan295.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan296.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan297.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan298.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan3.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan30.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan31.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan32.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan33.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan34.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan35.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan36.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan37.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan38.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan39.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan4.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan40.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan41.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan42.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan43.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan44.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan45.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan46.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan47.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan48.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan49.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan5.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan50.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan51.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan52.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan53.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan54.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan55.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan56.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan57.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan58.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan59.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan6.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan60.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan61.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan62.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan63.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan64.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan65.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan66.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan67.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan68.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan69.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan7.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan70.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan71.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan72.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan73.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan74.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan75.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan76.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan77.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan78.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan79.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan8.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan80.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan81.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan82.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan83.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan84.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan85.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan86.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan87.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan88.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan89.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan9.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan90.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan91.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan92.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan93.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan94.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan95.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan96.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan97.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan98.png',
#   './dataset/cropped/Shahrukh Khan\\Shahrukh Khan99.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'Alia Bhatt': 0, 'Deepika Padukone': 1, 'Salman khan': 2, 'Shahrukh Khan': 3}

# %% [markdown]
# ### Images in cropped folder can be used for model training. We will use these raw images along with wavelet transformed images to train our classifier. Let's prepare X and y now

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
32*32*3 + 32*32
# Out:
# 4096

# %%
X[0]
# Out:
# array([[156],
#        [152],
#        [114],
#        ...,
#        [ 90],
#        [176],
#        [178]], dtype=uint8)

# %%
y[0]
# Out:
# 0

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (1368, 4096)

# %% [markdown]
# ### Data cleaning process is done. Now we are ready to train our model

# %% [markdown]
# We will use SVM with rbf kernel tuned  with heuristic finetuning

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.8888888888888888

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.90      0.92        92
#            1       0.85      0.91      0.88       105
#            2       0.85      0.97      0.90        63
#            3       0.93      0.78      0.85        82
#
#     accuracy                           0.89       342
#    macro avg       0.89      0.89      0.89       342
# weighted avg       0.89      0.89      0.89       342

# %% [markdown]
# ### Let's use GridSearch to try out different models with different paramets. Goal is to come up with best modle with best fine tuned parameters

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.857722
# 1        random_forest    0.658859
# 2  logistic_regression    0.845034
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.868421052631579

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.716374269005848

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.8654970760233918

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[ 7,  0,  0,  0,  0],
#        [ 0,  9,  0,  1,  0],
#        [ 0,  0,  5,  2,  0],
#        [ 0,  1,  0,  6,  0],
#        [ 0,  0,  0,  0, 11]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'lionel_messi': 0,
#  'maria_sharapova': 1,
#  'roger_federer': 2,
#  'serena_williams': 3,
#  'virat_kohli': 4}

# %% [markdown]
# ### Save the trained model

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in c:\programdata\anaconda3\lib\site-packages (0.15.1)
# ['saved_model.pkl']

# %% [markdown]
# ### Save class dictionary

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
